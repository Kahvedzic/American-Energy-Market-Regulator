# %% [markdown]
# <center><h1 style="color:#D4AF37"> ⚡⚡ AEMR Data Analysis ⚡⚡</h1>

# %% [markdown]
# # <span style="color: green;">What's the Business Problem? 💰</span>
# The American Energy Market Regulator (AEMR) is responsible for looking after the United States of America’s domestic energy network. The regulator’s responsibility is to ensure that America’s energy network remains reliable with minimal disruptions, which are known as outages.
#
# There are four key types of outages:
#
# ● `Consequential` – This outage is caused by an exogenous event or a
# consequence of work unrelated to the energy provider (i.e. A transmission line
# may be down, which means that a particular power provider may be unable to
# send energy to the network)
#
# ● `Forced` – This outage is caused by a situation that has forced the power
# generating asset to be unavailable. In other words, it has caught the AEMR by
# surprise and was not planned. (i.e. A cooling tower that supplies water to cool
# down a power-generating asset has broken down, which has now forced the
# power-generating asset offline as the temperature can no longer be regulated
# properly.)
#
# ● `Opportunistic` – This outage arises when an energy provider wishes to be
# proactive with the maintenance of their assets and believes that it can complete
# maintenance on its plant within a 48-hour window. If it takes longer than this, the
# outage is considered a PLANNED outage as it was planned in advance and will
# take longer than 48 hours.
#
# ● `Planned` – This outage arises when an energy provider reports to the AEMR that
# an energy-generating asset needs to be taken offline for routine or planned
# maintenance activities to ensure the reliability of the asset in the future.
# Of the four outage types, the only one the AEMR penalizes is a forced outage, as this
# means that, if enough energy providers enter the forced outage state and the demand
# for energy is greater than the amount of energy that can be supplied, stress will be put
# on the energy system. This will then threaten the reliability of the network which is what
# the AEMR wishes to avoid.
#
# Of the four outage types, the only one the AEMR penalizes is a forced outage, as this
# means that, if enough energy providers enter the forced outage state and the demand
# for energy is greater than the amount of energy that can be supplied, stress will be put
# on the energy system. This will then threaten the reliability of the network which is what
# the AEMR wishes to avoid.
#
# Recently, the AEMR management team has been increasingly aware of a large number of energy providers that submitted outages over
# the 2016 and 2017 calendar years. The management team has expressed a desire to have the following two areas of concern addressed:
#
# A) Energy Stability and Market Outages
#
# B) Energy Losses and Market Reliability
#
# As an analyst within the data and reporting team, we've been asked to address these two immediate areas of concern

# %%
# %%capture
# !pip install ipython-sql sqlalchemy
import sqlalchemy
sqlalchemy.create_engine("sqlite:///AEMR.db")
# %load_ext sql
# %sql sqlite:///AEMR.db

# %%
# %%js
# require(['notebook/js/codecell'], function (codecell) {
#     codecell.CodeCell.options_default.highlight_modes['magic_text/x-mssql'] = { 'reg': [/%?%sql/] };
#     Jupyter.notebook.events.one('kernel_ready.Kernel', function () {
#         Jupyter.notebook.get_cells().map(function (cell) {
#             if (cell.cell_type == 'code') { cell.auto_highlight(); }
#         });
#     });
# });

# %% [markdown]
# ### <span style="color: green;">Energy stability is one of the key themes the AEMR management team cares about To ensure energy security and reliability, AEMR needs to understand the following:</span>
#
# * **What are the most common outage types and how long do they tend to last?**
# * **How frequently do the outages occur?**
# * **Are there any energy providers which have more outages than their peers which may be indicative of being unreliable?**
# ### <span style="color: green;">Please note that throughout the entire analysis, we are interested ONLY in the Outages where Status = Approved.</span>
# ### <span style="color: green;">We don't have any interest in Outages that were cancelled or not approved.</span>
# ### <span style="color: green;">This means our WHERE Clause will ALWAYS contain the field Where Status = Approved.</span>

# %% [markdown]
# <h3 style="color:#D4AF37"> Step One </h3>

# %% [markdown]
# COUNT the number of valid (i.e. Status = Approved) Outage Events sorted by their respective Outage_Reason i.e. `Forced`, `Consequential`, `Scheduled`, `Opportunistic`) over the 2016 & 2017 Periods.

# %%
# %%sql
# SELECT COUNT(*) as Total_Number_Outages,
#  Outage_Reason, year
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
# GROUP BY Outage_Reason,year
# LIMIT 10
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(181, 'Consequential', 2016),
#  (127, 'Consequential', 2017),
#  (1264, 'Forced', 2016),
#  (1622, 'Forced', 2017),
#  (106, 'Opportunistic Maintenance (Planned)', 2016),
#  (102, 'Opportunistic Maintenance (Planned)', 2017),
#  (380, 'Scheduled (Planned)', 2016),
#  (320, 'Scheduled (Planned)', 2017)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Two </h3>

# %% [markdown]
# i) Show the Total of all Outage Types (`Forced`, `Consequential`, `Scheduled`, `Opportunistic`) where the Status = Approved, that occurred for both 2016 and 2017, grouped by Year and Month. per month (i.e. 1 – 12). Order by Year, Month, Total_Number_Outages in Descending Order.
#
# ii) Building on the query we wrote in i), group the results by Outage Type, Year and Month. This is so we can identify whether there is any outage type specifically increasing on a monthly basis when comparing 2016 to 2017.

# %%
# %%sql
# SELECT
# COUNT (*) AS Total_Number_Outages,
# year,
# month
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY year, month
# LIMIT 10
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(191, 2016, 1),
#  (227, 2016, 2),
#  (136, 2016, 3),
#  (134, 2016, 4),
#  (174, 2016, 5),
#  (168, 2016, 6),
#  (147, 2016, 7),
#  (194, 2016, 8),
#  (124, 2016, 9),
#  (124, 2016, 10)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Three </h3>

# %% [markdown]
# Calculate 1) The `Total_Number_Outage_Events` and 2) The `Average Duration in DAYS` for each Participant Code and Outage Type over the 2016 and 2017 Period where the Status = Approved. Order by `Total_Number_Outage_Events` in Descending Order, Reason and Year.

# %%
# %%sql
# SELECT
# COUNT (*) AS Total_Number_Outage_Events,
# ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days,
# Participant_Code,
# Outage_Reason,
# year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Participant_Code, Outage_Reason, year
# ORDER BY Total_Number_Outage_Events DESC
# LIMIT 10
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(490, 0.07, 'AURICON', 'Forced', 2017),
#  (317, 0.38, 'GW', 'Forced', 2016),
#  (227, 1.06, 'GW', 'Forced', 2017),
#  (208, 0.07, 'AURICON', 'Forced', 2016),
#  (206, 0.08, 'AUXC', 'Forced', 2016),
#  (177, 2.28, 'MELK', 'Forced', 2017),
#  (172, 0.42, 'TRMOS', 'Forced', 2017),
#  (157, 0.83, 'MELK', 'Forced', 2016),
#  (135, 0.25, 'PUG', 'Forced', 2017),
#  (120, 0.02, 'AUXC', 'Forced', 2017)]

# %% [markdown]
# Now we're getting somewhere...!
# We've identified participants who are having many outages, as well as participants who have been offline for the longest durations.
#
# Armed with this information, it's important we're able to classify our participants accordingly based on reliability metrics of uptime.
#
# We classify a participant based off the following criteria:
# <b>
# **<li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day)</li>**
# **<li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours </li>**
# **<li> Low Risk - On average, the participant is unavailable for less than 12 Hours</li>**
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Four </h3>

# %% [markdown]
# Classify each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification` that is based off their Average Outage Duration Time. Please note that this is for all valid (i.e. Where status = approved) outage types (`Forced`, `Consequential`, `Scheduled`, `Opportunistic`) for all participant codes from 2016 to 2017. Order the results using `Average Duration Time In Days` in descending order.

# %%
# %%sql
# WITH CTE1 AS (
# SELECT
# COUNT (*) AS Total_Number_Outage_Events,
# ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days,
# Participant_Code,
# Outage_Reason,
# year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Participant_Code, Outage_Reason, year
# ORDER BY Total_Number_Outage_Events DESC
#
# )
#
# SELECT *,
# CASE
#     WHEN Average_Outage_Duration_In_Days > 1 THEN "High Risk"
#     WHEN Average_Outage_Duration_In_Days  BETWEEN .5 AND 1 THEN "Medium Risk"
#     WHEN Average_Outage_Duration_In_Days  BETWEEN 0 AND .5 THEN "Low Risk"
#     ELSE 'N/A'
#     END AS Risk_Classification
#
# FROM CTE1;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(490, 0.07, 'AURICON', 'Forced', 2017, 'Low Risk'),
#  (317, 0.38, 'GW', 'Forced', 2016, 'Low Risk'),
#  (227, 1.06, 'GW', 'Forced', 2017, 'High Risk'),
#  (208, 0.07, 'AURICON', 'Forced', 2016, 'Low Risk'),
#  (206, 0.08, 'AUXC', 'Forced', 2016, 'Low Risk'),
#  (177, 2.28, 'MELK', 'Forced', 2017, 'High Risk'),
#  (172, 0.42, 'TRMOS', 'Forced', 2017, 'Low Risk'),
#  (157, 0.83, 'MELK', 'Forced', 2016, 'Medium Risk'),
#  (135, 0.25, 'PUG', 'Forced', 2017, 'Low Risk'),
#  (120, 0.02, 'AUXC', 'Forced', 2017, 'Low Risk'),
#  (85, 4.61, 'MELK', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (81, 1.22, 'PJRH', 'Forced', 2016, 'High Risk'),
#  (76, 1.21, 'KORL', 'Forced', 2017, 'High Risk'),
#  (72, 0.84, 'PJRH', 'Forced', 2017, 'Medium Risk'),
#  (70, 6.89, 'MELK', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (69, 0.49, 'PMC', 'Forced', 2016, 'Low Risk'),
#  (65, 0.19, 'TRMOS', 'Forced', 2016, 'Low Risk'),
#  (53, 0.38, 'KORL', 'Forced', 2016, 'Low Risk'),
#  (46, 1.89, 'AURICON', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (45, 1.45, 'AURICON', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (45, 1.38, 'COLLGAR', 'Forced', 2017, 'High Risk'),
#  (45, 4.43, 'GW', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (42, 0.21, 'AURICON', 'Consequential', 2017, 'Low Risk'),
#  (41, 0.13, 'AURICON', 'Consequential', 2016, 'Low Risk'),
#  (40, 0.04, 'PMC', 'Forced', 2017, 'Low Risk'),
#  (39, 0.24, 'PJRH', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (38, 2.37, 'PJRH', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (37, 4.96, 'ENRG', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (35, 2.61, 'PJRH', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (30, 0.44, 'TSLA_MGT', 'Consequential', 2016, 'Low Risk'),
#  (29, 1.11, 'COLLGAR', 'Forced', 2016, 'High Risk'),
#  (29, 4.85, 'ENRG', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (28, 0.99, 'TSLA_MGT', 'Scheduled (Planned)', 2017, 'Medium Risk'),
#  (27, 1.9, 'PMC', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (26, 2.65, 'GW', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (24, 0.71, 'MELK', 'Opportunistic Maintenance (Planned)', 2016, 'Medium Risk'),
#  (24, 0.92, 'PUG', 'Forced', 2016, 'Medium Risk'),
#  (23, 0.18, 'PJRH', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (23, 0.34, 'TSLA_MGT', 'Consequential', 2017, 'Low Risk'),
#  (23, 1.97, 'TSLA_MGT', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (21, 2.24, 'ENRG', 'Forced', 2016, 'High Risk'),
#  (20, 0.18, 'GW', 'Consequential', 2016, 'Low Risk'),
#  (20, 0.31, 'GW', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (20, 6.96, 'KORL', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (18, 3.53, 'MUND', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (18, 0.26, 'STHRNCRS', 'Forced', 2017, 'Low Risk'),
#  (17, 0.41, 'EUCT', 'Consequential', 2016, 'Low Risk'),
#  (16, 3.38, 'KORL', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (16, 0.65, 'MELK', 'Opportunistic Maintenance (Planned)', 2017, 'Medium Risk'),
#  (16, 1.47, 'PUG', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (15, 0.57, 'ENRG', 'Consequential', 2016, 'Medium Risk'),
#  (15, 0.19, 'MUND', 'Forced', 2017, 'Low Risk'),
#  (14, 0.32, 'EUCT', 'Consequential', 2017, 'Low Risk'),
#  (14, 0.22, 'KORL', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (14, 0.68, 'STHRNCRS', 'Scheduled (Planned)', 2017, 'Medium Risk'),
#  (13, 0.28, 'GW', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (13, 0.33, 'STHRNCRS', 'Forced', 2016, 'Low Risk'),
#  (13, 0.62, 'STHRNCRS', 'Scheduled (Planned)', 2016, 'Medium Risk'),
#  (12, 0.6, 'COLLGAR', 'Consequential', 2016, 'Medium Risk'),
#  (12, 4.28, 'COLLGAR', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (12, 0.24, 'DNHR', 'Consequential', 2017, 'Low Risk'),
#  (12, 0.28, 'MCG', 'Forced', 2017, 'Low Risk'),
#  (12, 1.7, 'PMC', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (11, 0.28, 'DNHR', 'Consequential', 2016, 'Low Risk'),
#  (11, 5.9, 'EUCT', 'Forced', 2016, 'High Risk'),
#  (11, 2.25, 'PUG', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (10, 0.24, 'KORL', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (10, 0.28, 'PMC', 'Consequential', 2016, 'Low Risk'),
#  (9, 6.36, 'COLLGAR', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (9, 0.21, 'MUND', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (9, 0.22, 'STHRNCRS', 'Consequential', 2016, 'Low Risk'),
#  (8, 0.15, 'MUND', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (8, 3.52, 'PMC', 'Consequential', 2017, 'High Risk'),
#  (8, 3.44, 'WGUTD', 'Forced', 2017, 'High Risk'),
#  (7, 0.27, 'ENRG', 'Consequential', 2017, 'Low Risk'),
#  (7, 0.26, 'ENRG', 'Forced', 2017, 'Low Risk'),
#  (7, 0.76, 'MELK', 'Consequential', 2016, 'Medium Risk'),
#  (7, 1.7, 'MUND', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (7, 0.21, 'PUG', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (6, 2.24, 'KORL', 'Consequential', 2017, 'High Risk'),
#  (6, 1.99, 'WGUTD', 'Consequential', 2016, 'High Risk'),
#  (5, 0.23, 'COLLGAR', 'Consequential', 2017, 'Low Risk'),
#  (5, 0.33, 'COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (5, 1.42, 'TRMOS', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (4, 0.47, 'ENRG', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (4, 0.24, 'GW', 'Consequential', 2017, 'Low Risk'),
#  (4, 0.06, 'MCG', 'Scheduled (Planned)', 2017, 'Low Risk'),
#  (4, 0.37, 'MUND', 'Forced', 2016, 'Low Risk'),
#  (4, 2.31, 'TRMOS', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (4, 0.31, 'TSLA_MGT', 'Forced', 2017, 'Low Risk'),
#  (3, 0.33, 'AURICON', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (3, 0.35, 'ENRG', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (3, 0.03, 'EUCT', 'Forced', 2017, 'Low Risk'),
#  (3, 0.24, 'PUG', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (2, 1.25, 'AUXC', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (2, 0.26, 'MCG', 'Consequential', 2016, 'Low Risk'),
#  (2, 0.23, 'MCG', 'Consequential', 2017, 'Low Risk'),
#  (2, 0.26, 'STHRNCRS', 'Consequential', 2017, 'Low Risk'),
#  (2, 0.25, 'TSLA_MGT', 'Forced', 2016, 'Low Risk'),
#  (2, 0.02, 'WGUTD', 'Forced', 2016, 'Low Risk'),
#  (2, 0.05, 'WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (1, 0.96, 'AUXC', 'Consequential', 2016, 'Medium Risk'),
#  (1, 0.1, 'AUXC', 'Consequential', 2017, 'Low Risk'),
#  (1, 2.88, 'AUXC', 'Scheduled (Planned)', 2017, 'High Risk'),
#  (1, 0.4, 'DNHR', 'Forced', 2016, 'Low Risk'),
#  (1, 0.48, 'DNHR', 'Forced', 2017, 'Low Risk'),
#  (1, 0.79, 'MCG', 'Forced', 2016, 'Medium Risk'),
#  (1, 1.42, 'MCG', 'Scheduled (Planned)', 2016, 'High Risk'),
#  (1, 0.08, 'PMC', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (1, 0.25, 'PMC', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (1, 0.06, 'STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (1, 0.06, 'TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (1, 0.04, 'WGUTD', 'Consequential', 2017, 'Low Risk'),
#  (1, 0.6, 'WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 'Medium Risk'),
#  (1, 10.58, 'WGUTD', 'Scheduled (Planned)', 2017, 'High Risk')]

# %% [markdown]
# Now that we've classified our participants as either `High Risk`, `Medium Risk` or `Low Risk`, we want to dig a little deeper.
#
# Does it make sense that `Consequential`, `Opportunistic` or `Planned` aren't considered regarding the Risk Category?
#
# Perhaps we should refine our category accordingly by ensuring we focus our Risk Category on labelling only `Forced` Outages as being a Risk. After all, Forced Outages are the unplanned outages that risk the security of the electricity grid.
#
# Let's add two additional criteria to our classification considering `Total Number of Outage Events` and `Outage Type`.
#
# We've summarised these below:
#
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day) OR the Total Number of Outage Events > 20 </li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours OR the Total Number of Outage Events is Between 10 and 20 </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours OR the Total Number of Outage Events < 10 </li>
# <li> If Outage Type is not forced, then N/A
# </b>

# %% [markdown]
# Classifies each participant code as either High Risk, Medium Risk or Low Risk in a column called Risk_Classification using the new classification criteria. Order the results using Average Duration Time In Days in descending order.

# %%
# %%sql
# WITH CTE1 AS (
# SELECT
# COUNT (*) AS Total_Number_Outage_Events,
# ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days,
# Participant_Code,
# Outage_Reason,
# year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Participant_Code, Outage_Reason, year
# ORDER BY Total_Number_Outage_Events DESC
#
# )
#
# SELECT *,
# CASE
#     WHEN Average_Outage_Duration_In_Days > 1 AND Outage_Reason = 'Forced' OR Total_Number_Outage_Events > 20 AND Outage_Reason = 'Forced' THEN "High Risk"
#     WHEN Average_Outage_Duration_In_Days  BETWEEN .5 AND 1 and Outage_Reason = 'Forced' OR Total_Number_Outage_Events BETWEEN 10 AND 20 AND Outage_Reason = 'Forced' THEN "Medium Risk"
#     WHEN Average_Outage_Duration_In_Days  BETWEEN 0 AND .5 THEN "Low Risk"
#     ELSE 'N/A'
#     END AS Risk_Classification
#
# FROM CTE1;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(490, 0.07, 'AURICON', 'Forced', 2017, 'High Risk'),
#  (317, 0.38, 'GW', 'Forced', 2016, 'High Risk'),
#  (227, 1.06, 'GW', 'Forced', 2017, 'High Risk'),
#  (208, 0.07, 'AURICON', 'Forced', 2016, 'High Risk'),
#  (206, 0.08, 'AUXC', 'Forced', 2016, 'High Risk'),
#  (177, 2.28, 'MELK', 'Forced', 2017, 'High Risk'),
#  (172, 0.42, 'TRMOS', 'Forced', 2017, 'High Risk'),
#  (157, 0.83, 'MELK', 'Forced', 2016, 'High Risk'),
#  (135, 0.25, 'PUG', 'Forced', 2017, 'High Risk'),
#  (120, 0.02, 'AUXC', 'Forced', 2017, 'High Risk'),
#  (85, 4.61, 'MELK', 'Scheduled (Planned)', 2016, 'N/A'),
#  (81, 1.22, 'PJRH', 'Forced', 2016, 'High Risk'),
#  (76, 1.21, 'KORL', 'Forced', 2017, 'High Risk'),
#  (72, 0.84, 'PJRH', 'Forced', 2017, 'High Risk'),
#  (70, 6.89, 'MELK', 'Scheduled (Planned)', 2017, 'N/A'),
#  (69, 0.49, 'PMC', 'Forced', 2016, 'High Risk'),
#  (65, 0.19, 'TRMOS', 'Forced', 2016, 'High Risk'),
#  (53, 0.38, 'KORL', 'Forced', 2016, 'High Risk'),
#  (46, 1.89, 'AURICON', 'Scheduled (Planned)', 2016, 'N/A'),
#  (45, 1.45, 'AURICON', 'Scheduled (Planned)', 2017, 'N/A'),
#  (45, 1.38, 'COLLGAR', 'Forced', 2017, 'High Risk'),
#  (45, 4.43, 'GW', 'Scheduled (Planned)', 2016, 'N/A'),
#  (42, 0.21, 'AURICON', 'Consequential', 2017, 'Low Risk'),
#  (41, 0.13, 'AURICON', 'Consequential', 2016, 'Low Risk'),
#  (40, 0.04, 'PMC', 'Forced', 2017, 'High Risk'),
#  (39, 0.24, 'PJRH', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (38, 2.37, 'PJRH', 'Scheduled (Planned)', 2016, 'N/A'),
#  (37, 4.96, 'ENRG', 'Scheduled (Planned)', 2017, 'N/A'),
#  (35, 2.61, 'PJRH', 'Scheduled (Planned)', 2017, 'N/A'),
#  (30, 0.44, 'TSLA_MGT', 'Consequential', 2016, 'Low Risk'),
#  (29, 1.11, 'COLLGAR', 'Forced', 2016, 'High Risk'),
#  (29, 4.85, 'ENRG', 'Scheduled (Planned)', 2016, 'N/A'),
#  (28, 0.99, 'TSLA_MGT', 'Scheduled (Planned)', 2017, 'N/A'),
#  (27, 1.9, 'PMC', 'Scheduled (Planned)', 2016, 'N/A'),
#  (26, 2.65, 'GW', 'Scheduled (Planned)', 2017, 'N/A'),
#  (24, 0.71, 'MELK', 'Opportunistic Maintenance (Planned)', 2016, 'N/A'),
#  (24, 0.92, 'PUG', 'Forced', 2016, 'High Risk'),
#  (23, 0.18, 'PJRH', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (23, 0.34, 'TSLA_MGT', 'Consequential', 2017, 'Low Risk'),
#  (23, 1.97, 'TSLA_MGT', 'Scheduled (Planned)', 2016, 'N/A'),
#  (21, 2.24, 'ENRG', 'Forced', 2016, 'High Risk'),
#  (20, 0.18, 'GW', 'Consequential', 2016, 'Low Risk'),
#  (20, 0.31, 'GW', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (20, 6.96, 'KORL', 'Scheduled (Planned)', 2016, 'N/A'),
#  (18, 3.53, 'MUND', 'Scheduled (Planned)', 2016, 'N/A'),
#  (18, 0.26, 'STHRNCRS', 'Forced', 2017, 'Medium Risk'),
#  (17, 0.41, 'EUCT', 'Consequential', 2016, 'Low Risk'),
#  (16, 3.38, 'KORL', 'Scheduled (Planned)', 2017, 'N/A'),
#  (16, 0.65, 'MELK', 'Opportunistic Maintenance (Planned)', 2017, 'N/A'),
#  (16, 1.47, 'PUG', 'Scheduled (Planned)', 2016, 'N/A'),
#  (15, 0.57, 'ENRG', 'Consequential', 2016, 'N/A'),
#  (15, 0.19, 'MUND', 'Forced', 2017, 'Medium Risk'),
#  (14, 0.32, 'EUCT', 'Consequential', 2017, 'Low Risk'),
#  (14, 0.22, 'KORL', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (14, 0.68, 'STHRNCRS', 'Scheduled (Planned)', 2017, 'N/A'),
#  (13, 0.28, 'GW', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (13, 0.33, 'STHRNCRS', 'Forced', 2016, 'Medium Risk'),
#  (13, 0.62, 'STHRNCRS', 'Scheduled (Planned)', 2016, 'N/A'),
#  (12, 0.6, 'COLLGAR', 'Consequential', 2016, 'N/A'),
#  (12, 4.28, 'COLLGAR', 'Scheduled (Planned)', 2016, 'N/A'),
#  (12, 0.24, 'DNHR', 'Consequential', 2017, 'Low Risk'),
#  (12, 0.28, 'MCG', 'Forced', 2017, 'Medium Risk'),
#  (12, 1.7, 'PMC', 'Scheduled (Planned)', 2017, 'N/A'),
#  (11, 0.28, 'DNHR', 'Consequential', 2016, 'Low Risk'),
#  (11, 5.9, 'EUCT', 'Forced', 2016, 'High Risk'),
#  (11, 2.25, 'PUG', 'Scheduled (Planned)', 2017, 'N/A'),
#  (10, 0.24, 'KORL', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (10, 0.28, 'PMC', 'Consequential', 2016, 'Low Risk'),
#  (9, 6.36, 'COLLGAR', 'Scheduled (Planned)', 2017, 'N/A'),
#  (9, 0.21, 'MUND', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (9, 0.22, 'STHRNCRS', 'Consequential', 2016, 'Low Risk'),
#  (8, 0.15, 'MUND', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (8, 3.52, 'PMC', 'Consequential', 2017, 'N/A'),
#  (8, 3.44, 'WGUTD', 'Forced', 2017, 'High Risk'),
#  (7, 0.27, 'ENRG', 'Consequential', 2017, 'Low Risk'),
#  (7, 0.26, 'ENRG', 'Forced', 2017, 'Low Risk'),
#  (7, 0.76, 'MELK', 'Consequential', 2016, 'N/A'),
#  (7, 1.7, 'MUND', 'Scheduled (Planned)', 2017, 'N/A'),
#  (7, 0.21, 'PUG', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (6, 2.24, 'KORL', 'Consequential', 2017, 'N/A'),
#  (6, 1.99, 'WGUTD', 'Consequential', 2016, 'N/A'),
#  (5, 0.23, 'COLLGAR', 'Consequential', 2017, 'Low Risk'),
#  (5, 0.33, 'COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (5, 1.42, 'TRMOS', 'Scheduled (Planned)', 2016, 'N/A'),
#  (4, 0.47, 'ENRG', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (4, 0.24, 'GW', 'Consequential', 2017, 'Low Risk'),
#  (4, 0.06, 'MCG', 'Scheduled (Planned)', 2017, 'Low Risk'),
#  (4, 0.37, 'MUND', 'Forced', 2016, 'Low Risk'),
#  (4, 2.31, 'TRMOS', 'Scheduled (Planned)', 2017, 'N/A'),
#  (4, 0.31, 'TSLA_MGT', 'Forced', 2017, 'Low Risk'),
#  (3, 0.33, 'AURICON', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (3, 0.35, 'ENRG', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (3, 0.03, 'EUCT', 'Forced', 2017, 'Low Risk'),
#  (3, 0.24, 'PUG', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (2, 1.25, 'AUXC', 'Scheduled (Planned)', 2016, 'N/A'),
#  (2, 0.26, 'MCG', 'Consequential', 2016, 'Low Risk'),
#  (2, 0.23, 'MCG', 'Consequential', 2017, 'Low Risk'),
#  (2, 0.26, 'STHRNCRS', 'Consequential', 2017, 'Low Risk'),
#  (2, 0.25, 'TSLA_MGT', 'Forced', 2016, 'Low Risk'),
#  (2, 0.02, 'WGUTD', 'Forced', 2016, 'Low Risk'),
#  (2, 0.05, 'WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (1, 0.96, 'AUXC', 'Consequential', 2016, 'N/A'),
#  (1, 0.1, 'AUXC', 'Consequential', 2017, 'Low Risk'),
#  (1, 2.88, 'AUXC', 'Scheduled (Planned)', 2017, 'N/A'),
#  (1, 0.4, 'DNHR', 'Forced', 2016, 'Low Risk'),
#  (1, 0.48, 'DNHR', 'Forced', 2017, 'Low Risk'),
#  (1, 0.79, 'MCG', 'Forced', 2016, 'Medium Risk'),
#  (1, 1.42, 'MCG', 'Scheduled (Planned)', 2016, 'N/A'),
#  (1, 0.08, 'PMC', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (1, 0.25, 'PMC', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (1, 0.06, 'STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 'Low Risk'),
#  (1, 0.06, 'TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 'Low Risk'),
#  (1, 0.04, 'WGUTD', 'Consequential', 2017, 'Low Risk'),
#  (1, 0.6, 'WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 'N/A'),
#  (1, 10.58, 'WGUTD', 'Scheduled (Planned)', 2017, 'N/A')]

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part II. Energy Losses & Market Reliability ⚡ </h3>

# %% [markdown]
# When an energy provider provides energy to the market, they are making a commitment to the market and saying; “We will supply X amount of energy to the market under a contractual obligation.” However, in a situation where the outages are Forced, the energy provider intended to provide energy but are unable to provide energy and are forced offline. If many energy providers are forced offline at the same time it could cause an energy security risk that AEMR needs to mitigate.
#
# To ensure this doesn’t happen, the AEMR is interested in exploring the following questions:
#
# Of the outage types in 2016 and 2017, what percent were Forced Outage(s)?
# What was the average duration for a forced outage during both 2016 and 2017? Have we seen an increase in the average duration of forced outages?
# Which energy providers tended to have the largest number of forced outages?

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Six </h3>

# %% [markdown]
# Calculate the proportion of Forced Outages that have occurred over the 2016 - 2017 Period.
# Do we observe any particular increases regarding any Outage Types over this period?

# %%
# %%sql
#
# SELECT
# COUNT(*) AS Total_Number_Outages,
# SUM(CASE WHEN Outage_Reason = 'Forced' THEN 1 ELSE 0 END)  AS  Total_Number_Forced_Outage_Events,
# ROUND(SUM(CASE WHEN Outage_Reason = 'Forced' THEN 1 ELSE 0 END)  * 1.0/COUNT(*)*100,2) AS Pct_Forced_Outages,
# Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY year
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(1931, 1264, 65.46, 2016), (2171, 1622, 74.71, 2017)]

# %% [markdown]
# Great. It's clear to see now that `Forced Outages` are problematic for us. Not only are they the only outage type that generates financial losses as the Outage is unplanned, it seems there is a number of Energy Participants who have been having a significantly high number of Outages.
#
# Let's break our analysis down into Macro and Micro Analysis.
# The total gives us the Overall Duration a participant is offline / has lost energy, however, it doesn't tell us how *frequently* this occurs. In other words, if we have one or two very big outages, it might contribute to very large totals.

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Seven </h3>

# %% [markdown]
# Calculate the `Total Number of Outages`, `Total Duration In Days`and `Total Energy Lost` of all valid `Outages` for each `participant code` and `facility_code`, sorted by `Total Energy Lost` in descending order and Ordered by the YEAR Category.

# %%
# %%sql
#
# SELECT
# COUNT(*) AS Total_Number_Outages,
# SUM(ABS((JULIANDAY(End_Time) - JULIANDAY(Start_Time)))) AS Total_Duration_In_Days,
# SUM(Energy_Lost_MW) AS Total_Energy_Lost,
# Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year
#
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Outage_Reason, Participant_code, Facility_Code, Year
# ORDER BY Total_Duration_In_Days, Year
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(1, 0.04166666651144624, 36.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (2, 0.041666666977107525, 54.0, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (1, 0.0625, 0.0, 'Opportunistic Maintenance (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (1, 0.0625, 23.0, 'Opportunistic Maintenance (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (1, 0.08333333348855376, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2016),
#  (3, 0.10416666651144624, 64.80000000000001, 'Forced', 'EUCT', 'GRASMERE_WF1', 2017),
#  (2, 0.10416666651144624, 72.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (1, 0.10416666697710752, 26.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2017),
#  (4, 0.22916666651144624, 220.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (1, 0.25, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2017),
#  (1, 0.3958333330228925, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (2, 0.45833333348855376, 94.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (1, 0.4791666669771075, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (2, 0.5, 160.0, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (2, 0.5208333330228925, 110.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (2, 0.5208333334885538, 46.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (1, 0.6041666665114462, 36.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (3, 0.7083333334885538, 348.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (1, 0.7916666665114462, 55.0, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (1, 0.9583333334885538, 25.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2016),
#  (4, 0.9583333334885538, 89.29000000000002, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (3, 0.9791666665114462, 523.0, 'Opportunistic Maintenance (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (3, 1.0416666665114462, 24.1, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (5, 1.1666666669771075, 926.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (8, 1.2083333330228925, 248.0, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (4, 1.2291666669771075, 169.9, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (1, 1.4166666665114462, 55.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (7, 1.479166666045785, 580.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (4, 1.4791666665114462, 147.2, 'Forced', 'MUND', 'MUNDARING_GT1', 2016),
#  (40, 1.5624999990686774, 5648.439, 'Forced', 'PMC', 'PMC_AG', 2017),
#  (5, 1.6458333330228925, 763.956, 'Opportunistic Maintenance (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (7, 1.8541666669771075, 191.856, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (7, 1.8749999986030161, 63.8, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (4, 1.8958333330228925, 87.0, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (9, 1.8958333334885538, 335.858, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (9, 1.9375, 207.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (120, 2.1041666669771075, 1768.7600000000004, 'Forced', 'AUXC', 'AUXC_WGP', 2017),
#  (10, 2.4166666665114462, 842.8000000000001, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (2, 2.5, 50.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2016),
#  (10, 2.8124999995343387, 643.0, 'Consequential', 'PMC', 'PMC_AG', 2016),
#  (15, 2.854166667442769, 398.5810000000001, 'Forced', 'MUND', 'MUNDARING_GT1', 2017),
#  (1, 2.875, 26.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2017),
#  (12, 2.8958333330228925, 17.279999999999998, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (14, 3.041666666045785, 1172.05, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (11, 3.1249999995343387, 15.839999999999996, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (12, 3.3958333334885538, 563.333, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (20, 3.6041666651144624, 832.7199999999999, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (13, 3.6666666669771075, 1423.526, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (23, 4.2083333330228925, 2178.9449999999997, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (13, 4.2916666669771075, 299.0, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (14, 4.520833333954215, 222.3, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2017),
#  (18, 4.645833333488554, 292.7, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (41, 5.312499999534339, 3925.548, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (7, 5.3541666669771075, 1524.8160000000003, 'Consequential', 'MELK', 'MELK_G7', 2016),
#  (20, 6.208333331160247, 2951.0, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (17, 6.95833333209157, 290.40000000000003, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2016),
#  (5, 7.083333332557231, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (12, 7.1458333330228925, 1374.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (23, 7.72916666790843, 227.70000000000007, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (13, 8.041666666511446, 299.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (15, 8.479166666511446, 161.4, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (42, 8.875000000465661, 2553.239999999999, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (39, 9.166666662320495, 3100.9469999999997, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (4, 9.229166666977108, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2017),
#  (14, 9.458333332557231, 322.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (16, 10.437499998137355, 1339.7, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2017),
#  (1, 10.583333333022892, 36.0, 'Scheduled (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (7, 11.895833333488554, 262.458, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (6, 11.958333333022892, 198.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (65, 12.625, 1232.4299999999996, 'Forced', 'TRMOS', 'TIWEST_COG1', 2016),
#  (30, 13.208333332557231, 297.0, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (6, 13.416666666977108, 505.947, 'Consequential', 'KORL', 'KORL_GT3', 2017),
#  (208, 15.062499997671694, 10696.275999999998, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (206, 16.041666666045785, 2734.1399999999985, 'Forced', 'AUXC', 'AUXC_WGP', 2016),
#  (24, 16.999999997206032, 2877.038, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2016),
#  (53, 20.000000001862645, 4040.3199999999983, 'Forced', 'KORL', 'KORL_GT3', 2016),
#  (12, 20.354166666977108, 1639.2000000000005, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2017),
#  (24, 22.166666666045785, 815.472, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (16, 23.562499999068677, 1334.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (11, 24.72916666744277, 1160.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (8, 27.541666666977108, 221.29399999999998, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (28, 27.75000000046566, 678.3999999999996, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (8, 28.145833333954215, 1672.664, 'Consequential', 'PMC', 'PMC_AG', 2017),
#  (29, 32.333333333954215, 4320.856, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (135, 33.39583333255723, 4112.0999999999985, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (490, 33.645833333954215, 21639.54899999999, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (69, 34.062499997671694, 9093.085, 'Forced', 'PMC', 'PMC_AG', 2016),
#  (23, 45.25, 448.7999999999998, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (21, 47.04166666790843, 1182.8, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (12, 51.37500000093132, 2139.868, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (27, 51.395833334419876, 4839.0, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2016),
#  (16, 54.104166666045785, 1326.6, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (9, 57.270833333488554, 1632.7799999999997, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (72, 60.12500000046566, 4839.280999999999, 'Forced', 'PJRH', 'PJRH_GT11', 2017),
#  (45, 62.10416666790843, 2787.057, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (18, 63.45833333162591, 664.0, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (11, 64.89583333395422, 64.8, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (45, 65.39583333116025, 5941.2480000000005, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (26, 68.89583333395422, 3812.418, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (172, 71.89583333814517, 5016.670000000002, 'Forced', 'TRMOS', 'TIWEST_COG1', 2017),
#  (46, 87.02083333022892, 6964.800000000003, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (38, 89.89583333302289, 2445.0, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (35, 91.35416666604578, 2110.013, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (76, 91.79166666511446, 4679.6810000000005, 'Forced', 'KORL', 'KORL_GT3', 2017),
#  (81, 98.79166666697711, 5881.52, 'Forced', 'PJRH', 'PJRH_GT11', 2016),
#  (317, 120.6041666646488, 15751.381000000003, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (157, 129.6041666669771, 13771.069999999994, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (20, 139.25, 1685.5999999999995, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (29, 140.60416666604578, 445.6000000000001, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (37, 183.58333333348855, 516.9200000000001, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (45, 199.3958333353512, 6450.0, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (227, 240.68749999580905, 19326.557999999997, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (85, 392.24999999813735, 9668.79, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2016),
#  (177, 404.1458333302289, 10285.395999999995, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (70, 482.5833333330229, 7499.281, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2017)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Eight </h3>

# %% [markdown]
# Calculate the `Average Duration In Days` and Average Energy Lost of all valid `FORCED OUTAGES` for each `participant_code` and `facility_code` sorted by Average Energy Lost in descending order and Ordered by the YEAR Category.

# %%
# %%sql
#
# SELECT
# ROUND(AVG(ABS((JULIANDAY(End_Time) - JULIANDAY(Start_Time)))),2) AS Avg_Duration_In_Days,
# ROUND(AVG(Energy_lost_MW),2) AS Avg_Energy_Lost,
# Outage_Reason,
# Participant_Code,
# Facility_code,
# Year
#
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Outage_reason, Participant_code, Facility_Code, Year
# ORDER BY Avg_Energy_Lost, Year DESC
# LIMIT 5
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(0.06, 0.0, 'Opportunistic Maintenance (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (0.24, 1.44, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (0.48, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (0.28, 1.44, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (0.4, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Nine </h3>

# %% [markdown]
# Calculate the `Average Energy Lost` and `Total Energy Lost` for each `Facility Code` and `Participant Code` across both the 2016 and 2017 periods when the Outage_Reason is set to Forced. Upon completion of this, calculate the percentage of energy lost due to forced outages for each Facility_Code. Please ORDER the query by Total Energy Lost from 2016 to 2017.
#
# Which participants have contributed the most to the Energy Lost due to Forced Outages?

# %%
# %%sql
#
# SELECT
# ROUND(AVG(Energy_Lost_MW),2) AS Avg_Energy_Lost,
# ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost,
# ROUND(SUM(Energy_Lost_MW) / (SELECT SUM(ENERGY_LOST_MW) FROM AEMR_Outage_Table WHERE Status = 'Approved' AND Outage_Reason = 'Forced')*100,2) AS Pct_Energy_Lost,
# Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year
#
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved' AND Outage_Reason = 'Forced'
# GROUP BY Outage_Reason, Participant_Code, Facility_Code, Year
# ORDER BY Total_Energy_Lost DESC, Year DESC
# LIMIT 5
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(44.16, 21639.55, 14.21, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (85.14, 19326.56, 12.69, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (49.69, 15751.38, 10.34, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (87.71, 13771.07, 9.04, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (51.42, 10696.28, 7.02, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Step Ten </h3>

# %% [markdown]
# Having identified the top 3 participants by Total Energy Loss being `GW`, `MELK` and `Auricon`; we now need to calculate the `Total_Energy_Lost` each of these three `Participant Codes` and the `Facility_Code`. Additionally, identify the Description_Of_Outage associated with the highest Total_Energy_Lost for each of the Participant_Codes and Facility_Code for each of the three participants.
#
# Lastly, calculate the percentage of Energy Loss, attributed to these reasons!

# %%
# %%sql
# SELECT
# *
# FROM (
# SELECT
# Participant_Code,
# Facility_Code,
# Description_Of_Outage,
# ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost,
# ROUND(SUM(Energy_Lost_MW) / (SELECT SUM(Energy_Lost_MW) FROM AEMR_Outage_Table WHERE Status = 'Approved' AND Outage_Reason = 'Forced')*100,2)As Pct_Forced,
# RANK() OVER (PARTITION BY Participant_Code, Facility_code ORDER BY SUM(Energy_Lost_MW) DESC) AS Ranking
# FROM AEMR_Outage_Table
# WHERE Participant_Code IN ('GW', 'MELK', 'AURICON') AND Status = 'Approved' AND Outage_Reason = 'Forced'
# GROUP BY Participant_Code, Facility_Code, Description_Of_Outage
# ORDER BY Participant_Code, Total_Energy_Lost DESC)
#
# WHERE Ranking = 1
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'AURICON_PNJ_U1', 'Full unit trip', 6033.87, 3.96, 1),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational Issues caused real time forced outage.', 28687.54, 18.84, 1),
#  ('MELK', 'MELK_G7', 'Safety Issues', 1100.0, 0.72, 1)]
